# %%
import numpy as np #Import relevant packages
import pandas as pd
import math
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
import glob
import csv
import matplotlib.pyplot as plt

def unpack_data(filepath): #Returns a dictionary where each item is a df containing one run. One dict per generation.
    all_files = glob.glob(filepath + "/*.csv")
    name_list = []
    datadict = {}
    for f in all_files:
        name_list.append(f[77:-4])
    for i,n in enumerate(name_list):
        datadict[n] = pd.read_csv(all_files[i], header=0)
    for k, v in datadict.items():
        v.drop(columns=["Unnamed: 0", "volume", "spread", "10_MA", "50_MA"], inplace=True)
    return datadict

def format_data(datadict, window): #Turn dictionaries of data into features and samples lists
    x_data = []
    y_data = []
    for k, v in datadict.items():
        for i in range(len(v)):
            if i >= window:
                y_data.append(v.iloc[i]["trading_price"])
                xi = v.iloc[i-window:i].to_numpy()
                x_data.append(xi)
    x_data = np.array(x_data)
    y_data = np.array(y_data)
    y_data = np.reshape(y_data, (y_data.shape[0], 1))
    return x_data, y_data

def normalise_data(xarray, yarray): #Take the natural log and then normalise prices
    yarray_log = np.log(yarray)
    xarray_log = np.log(xarray)
    xsc = StandardScaler()
    instances, timesteps, features = xarray_log.shape
    xarray_log = np.reshape(xarray_log, (-1, features))
    xarray_norm = xsc.fit_transform(xarray_log)
    xarray_norm = np.reshape(xarray_norm, (instances, timesteps, features))
    ysc = StandardScaler().fit(yarray_log)
    yarray_norm = ysc.transform(yarray_log)
    return xarray_norm, yarray_norm, xsc, ysc

def split_data(xarray, yarray, trainratio): #Split the data into training and test sets
    train_len = int(len(xarray)*trainratio)
    test_len = len(xarray) - train_len
    x_train, y_train, x_test, y_test = xarray[:train_len], yarray[:train_len], xarray[train_len:], yarray[train_len:]
    return x_train, y_train, x_test, y_test

# %%
gen39 = unpack_data("/Users/karangarg/Documents/Year 3 Modules/EC331/Code/rae_repo/simulations/gen39_sims/data")

# %%
X40, y40 = format_data(gen39, 20)
print(X40.shape)
print(y40.shape)
# Out:
# (31013, 20, 2)
# (31013, 1)

# %%
X40_train, y40_train, X40_test, y40_test = split_data(X40, y40, 0.8)

# %%
X40_train, y40_train, X40scale, y40scale = normalise_data(X40_train, y40_train)
X40_test, y40_test, _, _ = normalise_data(X40_test, y40_test)

# %%
print(X40scale.mean_)
print(X40scale.var_)
print(y40scale.mean_)
print(y40scale.var_)
# Out:
# [4.72521807 4.80378636]
# [0.13757034 0.01704397]
# [4.73164731]
# [0.14531644]

# %%
lstm40=keras.Sequential() #Set up the architecture of the model

lstm40.add(layers.LSTM(units=16, input_shape=(X40_train.shape[1], X40_train.shape[2])))
lstm40.add(layers.Dropout(0.2))

lstm40.add(layers.Dense(units=1))

print(lstm40.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm (LSTM)                  (None, 16)                1216
# _________________________________________________________________
# dropout (Dropout)            (None, 16)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 17
# ...
# Total params: 1,233
# Trainable params: 1,233
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
lstm40.compile(optimizer='nadam', loss='mean_squared_error') #Compile and train the model

history40 = lstm40.fit(X40_train, y40_train, epochs = 10, batch_size = 32, validation_split=0.2, shuffle=False)
# Out:
# Train on 19848 samples, validate on 4962 samples
# Epoch 1/10
# 19848/19848 [==============================] - 35s 2ms/sample - loss: 0.2357 - val_loss: 0.0010
# Epoch 2/10
# 19848/19848 [==============================] - 24s 1ms/sample - loss: 0.0374 - val_loss: 0.0018
# Epoch 3/10
# 19848/19848 [==============================] - 23s 1ms/sample - loss: 0.0321 - val_loss: 0.0012
# Epoch 4/10
# 19848/19848 [==============================] - 28s 1ms/sample - loss: 0.0266 - val_loss: 3.6112e-04
# Epoch 5/10
# 19848/19848 [==============================] - 26s 1ms/sample - loss: 0.0227 - val_loss: 7.7489e-04
# Epoch 6/10
# 19848/19848 [==============================] - 28s 1ms/sample - loss: 0.0279 - val_loss: 0.0011
# Epoch 7/10
# 19848/19848 [==============================] - 31s 2ms/sample - loss: 0.0222 - val_loss: 3.2366e-04
# Epoch 8/10
# 19848/19848 [==============================] - 26s 1ms/sample - loss: 0.0237 - val_loss: 3.2886e-04
# Epoch 9/10
# ...

# %%
lstm40.save("/Users/karangarg/Documents/Year 3 Modules/EC331/Code/rae_repo/lstms/lstm40")
# Out:
# WARNING:tensorflow:From /Users/karangarg/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1781: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: /Users/karangarg/Documents/Year 3 Modules/EC331/Code/rae_repo/lstms/lstm40/assets

# %%
plt.figure(figsize=(15,6))
plt.plot(history40.history["loss"], label="train")
plt.plot(history40.history["val_loss"], label="validation")
plt.legend()

# %%
y40_pred = lstm40.predict(X40_test)
y40_train_inv = y40scale.inverse_transform(y40_train.reshape(1, -1))
y40_test_inv = y40scale.inverse_transform(y40_test.reshape(1, -1))
y40_pred_inv = y40scale.inverse_transform(y40_pred)

# %%
plt.figure(figsize=(15,6))
plt.plot(y40_test_inv.flatten(), label="Test data")
plt.plot(y40_pred_inv.flatten(), label="Model prediction")
plt.legend()
