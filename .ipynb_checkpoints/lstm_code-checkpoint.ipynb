# %% [markdown]
# # Training the Algorithmic Traders
#
# This notebook contains the code for generating and training the LSTM traders. I have used the keras structures that are available with tensorflow as the basis for the struture. This particular notebook defines the functions needed for training and then trains and develops lstm1.

# %%
import numpy as np #Import relevant packages
import pandas as pd
import math
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
import glob
import csv
import matplotlib.pyplot as plt

# %%
def unpack_data(filepath): #Returns a dictionary where each item is a df containing one run. One dict per generation.
    all_files = glob.glob(filepath + "/*.csv")
    name_list = []
    datadict = {}
    for f in all_files:
        name_list.append(f[77:-4])
    for i,n in enumerate(name_list):
        datadict[n] = pd.read_csv(all_files[i], header=0)
    for k, v in datadict.items():
        v.drop(columns=["Unnamed: 0", "volume", "spread", "10_MA", "50_MA"], inplace=True)
    return datadict

# %%
gen0 = unpack_data("/Users/karangarg/Documents/Year 3 Modules/EC331/Code/rae_repo/gen0_sims/data") #Load gen0 data

# %%
def format_data(datadict, window): #Turn dictionaries of data into features and samples lists
    x_data = []
    y_data = []
    for k, v in datadict.items():
        for i in range(len(v)):
            if i >= window:
                y_data.append(v.iloc[i]["trading_price"])
                xi = v.iloc[i-window:i].to_numpy()
                x_data.append(xi)
    x_data = np.array(x_data)
    y_data = np.array(y_data)
    y_data = np.reshape(y_data, (y_data.shape[0], 1))
    return x_data, y_data

# %%
X, y = format_data(gen0, 10)
print(X.shape)
print(y.shape)
# Out:
# (32360, 10, 2)
# (32360, 1)

# %%
def normalise_data(xarray, yarray): #Take the natural log and then normalise prices
    yarray_log = np.log(yarray)
    xarray_log = np.log(xarray)
    xsc = StandardScaler()
    instances, timesteps, features = xarray_log.shape
    xarray_log = np.reshape(xarray_log, (-1, features))
    xarray_norm = xsc.fit_transform(xarray_log)
    xarray_norm = np.reshape(xarray_norm, (instances, timesteps, features))
    ysc = StandardScaler().fit(yarray_log)
    yarray_norm = ysc.transform(yarray_log)
    return xarray_norm, yarray_norm, xsc, ysc

def split_data(xarray, yarray, trainratio): #Split the data into training and test sets
    train_len = int(len(xarray)*trainratio)
    test_len = len(xarray) - train_len
    x_train, y_train, x_test, y_test = xarray[:train_len], yarray[:train_len], xarray[train_len:], yarray[train_len:]
    return x_train, y_train, x_test, y_test

# %%
X_train, y_train, X_test, y_test = split_data(X, y, 0.6)
X_train, y_train, Xscale, yscale = normalise_data(X_train, y_train)
X_test, y_test, _, _ = normalise_data(X_test, y_test)

# %%
print(Xscale.mean_)
print(Xscale.var_)
print(yscale.mean_)
print(yscale.var_)
# Out:
# [4.72072684 4.78073085]
# [0.04046444 0.01431437]
# [4.72363942]
# [0.04226946]

# %%
lstm1=keras.Sequential() #Set up the architecture of the model

lstm1.add(layers.LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
lstm1.add(layers.Dropout(0.4))

lstm1.add(layers.LSTM(units=50, return_sequences=True))
lstm1.add(layers.Dropout(0.4))

lstm1.add(layers.LSTM(units=50, return_sequences=True))
lstm1.add(layers.Dropout(0.4))

lstm1.add(layers.LSTM(units=50))
lstm1.add(layers.Dropout(0.4))

lstm1.add(layers.Dense(units=1))

# %%
lstm1.compile(optimizer='nadam', loss='mean_squared_error') #Compile and train the model

history1 = lstm1.fit(X_train, y_train, epochs = 100, batch_size = 32, validation_split=0.1, shuffle=False)
# Out:
# Train on 17474 samples, validate on 1942 samples
# Epoch 1/100
# 17474/17474 [==============================] - 172s 10ms/sample - loss: 0.0906 - val_loss: 0.1010
# Epoch 2/100
# 17474/17474 [==============================] - 101s 6ms/sample - loss: 0.0392 - val_loss: 0.0340
# Epoch 3/100
# 17474/17474 [==============================] - 98s 6ms/sample - loss: 0.0408 - val_loss: 0.0328
# Epoch 4/100
# 17474/17474 [==============================] - 108s 6ms/sample - loss: 0.0379 - val_loss: 0.0462
# Epoch 5/100
# 17474/17474 [==============================] - 109s 6ms/sample - loss: 0.0300 - val_loss: 0.0920
# Epoch 6/100
# 17474/17474 [==============================] - 103s 6ms/sample - loss: 0.0268 - val_loss: 0.1495
# Epoch 7/100
# 17474/17474 [==============================] - 102s 6ms/sample - loss: 0.0332 - val_loss: 0.1181
# Epoch 8/100
# 17474/17474 [==============================] - 98s 6ms/sample - loss: 0.0295 - val_loss: 0.1175
# Epoch 9/100
# 17474/17474 [==============================] - 103s 6ms/sample - loss: 0.0288 - val_loss: 0.1461
# Epoch 10/100
# 17474/17474 [==============================] - 114s 7ms/sample - loss: 0.0299 - val_loss: 0.1427
# Epoch 11/100
# 17474/17474 [==============================] - 122s 7ms/sample - loss: 0.0308 - val_loss: 0.2806
# Epoch 12/100
# 17474/17474 [==============================] - 106s 6ms/sample - loss: 0.0260 - val_loss: 0.1001
# Epoch 13/100
# 17474/17474 [==============================] - 96s 5ms/sample - loss: 0.0249 - val_loss: 0.2067
# Epoch 14/100
# 17474/17474 [==============================] - 106s 6ms/sample - loss: 0.0267 - val_loss: 0.1102
# Epoch 15/100
# 17474/17474 [==============================] - 108s 6ms/sample - loss: 0.0299 - val_loss: 0.1824
# Epoch 16/100
# 17474/17474 [==============================] - 105s 6ms/sample - loss: 0.0270 - val_loss: 0.2069
# Epoch 17/100
# 17474/17474 [==============================] - 96s 5ms/sample - loss: 0.0260 - val_loss: 0.1366
# Epoch 18/100
# 17474/17474 [==============================] - 95s 5ms/sample - loss: 0.0252 - val_loss: 0.2344
# Epoch 19/100
# 17474/17474 [==============================] - 104s 6ms/sample - loss: 0.0302 - val_loss: 0.2347
# Epoch 20/100
# 17474/17474 [==============================] - 101s 6ms/sample - loss: 0.0252 - val_loss: 0.2753
# Epoch 21/100
# 17474/17474 [==============================] - 102s 6ms/sample - loss: 0.0275 - val_loss: 0.2192
# Epoch 22/100
# 17474/17474 [==============================] - 104s 6ms/sample - loss: 0.0306 - val_loss: 0.1366
# Epoch 23/100
# 17474/17474 [==============================] - 138s 8ms/sample - loss: 0.0258 - val_loss: 0.1510
# Epoch 24/100
# 17474/17474 [==============================] - 119s 7ms/sample - loss: 0.0262 - val_loss: 0.1006
# Epoch 25/100
# 17474/17474 [==============================] - 111s 6ms/sample - loss: 0.0260 - val_loss: 0.0972
# Epoch 26/100
# 17474/17474 [==============================] - 137s 8ms/sample - loss: 0.0249 - val_loss: 0.1625
# Epoch 27/100
# 17474/17474 [==============================] - 108s 6ms/sample - loss: 0.0282 - val_loss: 0.1288
# Epoch 28/100
# 17474/17474 [==============================] - 92s 5ms/sample - loss: 0.0255 - val_loss: 0.0526
# Epoch 29/100
# 17474/17474 [==============================] - 91s 5ms/sample - loss: 0.0235 - val_loss: 0.0551
# Epoch 30/100
# 17474/17474 [==============================] - 100s 6ms/sample - loss: 0.0225 - val_loss: 0.0302
# Epoch 31/100
# 17474/17474 [==============================] - 112s 6ms/sample - loss: 0.0237 - val_loss: 0.1728
# Epoch 32/100
# 17474/17474 [==============================] - 121s 7ms/sample - loss: 0.0271 - val_loss: 0.1371
# Epoch 33/100
# 17474/17474 [==============================] - 106s 6ms/sample - loss: 0.0307 - val_loss: 0.0478
# Epoch 34/100
# 17474/17474 [==============================] - 113s 6ms/sample - loss: 0.0256 - val_loss: 0.0965
# Epoch 35/100
# 17474/17474 [==============================] - 113s 6ms/sample - loss: 0.0250 - val_loss: 0.1117
# Epoch 36/100
# 17474/17474 [==============================] - 102s 6ms/sample - loss: 0.0286 - val_loss: 0.0439
# Epoch 37/100
# 17474/17474 [==============================] - 101s 6ms/sample - loss: 0.0265 - val_loss: 0.1624
# Epoch 38/100
# 17474/17474 [==============================] - 82s 5ms/sample - loss: 0.0268 - val_loss: 0.0572
# Epoch 39/100
# 17474/17474 [==============================] - 62s 4ms/sample - loss: 0.0274 - val_loss: 0.0724
# Epoch 40/100
# 17474/17474 [==============================] - 61s 3ms/sample - loss: 0.0286 - val_loss: 0.0119
# Epoch 41/100
# 17474/17474 [==============================] - 59s 3ms/sample - loss: 0.0222 - val_loss: 0.0353
# Epoch 42/100
# 17474/17474 [==============================] - 65s 4ms/sample - loss: 0.0224 - val_loss: 0.0281
# Epoch 43/100
# 17474/17474 [==============================] - 66s 4ms/sample - loss: 0.0212 - val_loss: 0.0622
# Epoch 44/100
# 17474/17474 [==============================] - 84s 5ms/sample - loss: 0.0264 - val_loss: 0.1178
# Epoch 45/100
# 17474/17474 [==============================] - 74s 4ms/sample - loss: 0.0247 - val_loss: 0.0139
# Epoch 46/100
# 17474/17474 [==============================] - 73s 4ms/sample - loss: 0.0223 - val_loss: 0.0331
# Epoch 47/100
# 17474/17474 [==============================] - 73s 4ms/sample - loss: 0.0243 - val_loss: 0.0544
# Epoch 48/100
# 17474/17474 [==============================] - 94s 5ms/sample - loss: 0.0256 - val_loss: 0.0622
# Epoch 49/100
# 17474/17474 [==============================] - 79s 5ms/sample - loss: 0.0255 - val_loss: 0.0579
# Epoch 50/100
# 17474/17474 [==============================] - 76s 4ms/sample - loss: 0.0223 - val_loss: 0.1196
# Epoch 51/100
# 17474/17474 [==============================] - 82s 5ms/sample - loss: 0.0230 - val_loss: 0.0356
# Epoch 52/100
# 17474/17474 [==============================] - 86s 5ms/sample - loss: 0.0255 - val_loss: 0.0242
# Epoch 53/100
# 17474/17474 [==============================] - 90s 5ms/sample - loss: 0.0286 - val_loss: 0.0684
# Epoch 54/100
# 17474/17474 [==============================] - 132s 8ms/sample - loss: 0.0230 - val_loss: 0.0224
# Epoch 55/100
# 17474/17474 [==============================] - 119s 7ms/sample - loss: 0.0216 - val_loss: 0.0408
# Epoch 56/100
# 17474/17474 [==============================] - 111s 6ms/sample - loss: 0.0269 - val_loss: 0.0801
# Epoch 57/100
# 17474/17474 [==============================] - 95s 5ms/sample - loss: 0.0258 - val_loss: 0.0146
# Epoch 58/100
# 17474/17474 [==============================] - 117s 7ms/sample - loss: 0.0222 - val_loss: 0.1013
# Epoch 59/100
# 17474/17474 [==============================] - 127s 7ms/sample - loss: 0.0262 - val_loss: 0.0737
# Epoch 60/100
# 17474/17474 [==============================] - 110s 6ms/sample - loss: 0.0233 - val_loss: 0.0390
# Epoch 61/100
# 17474/17474 [==============================] - 111s 6ms/sample - loss: 0.0256 - val_loss: 0.0274
# Epoch 62/100
# 17474/17474 [==============================] - 103s 6ms/sample - loss: 0.0221 - val_loss: 0.0458
# Epoch 63/100
# 17474/17474 [==============================] - 112s 6ms/sample - loss: 0.0250 - val_loss: 0.0627
# Epoch 64/100
# 17474/17474 [==============================] - 94s 5ms/sample - loss: 0.0236 - val_loss: 0.0147
# Epoch 65/100
# 17474/17474 [==============================] - 101s 6ms/sample - loss: 0.0211 - val_loss: 0.0271
# Epoch 66/100
# 17474/17474 [==============================] - 99s 6ms/sample - loss: 0.0216 - val_loss: 0.0402
# Epoch 67/100
# 17474/17474 [==============================] - 90s 5ms/sample - loss: 0.0237 - val_loss: 0.0400
# Epoch 68/100
# 17474/17474 [==============================] - 117s 7ms/sample - loss: 0.0234 - val_loss: 0.0469
# Epoch 69/100
# 17474/17474 [==============================] - 107s 6ms/sample - loss: 0.0248 - val_loss: 0.0335
# Epoch 70/100
# 17474/17474 [==============================] - 115s 7ms/sample - loss: 0.0263 - val_loss: 0.0284
# Epoch 71/100
# 17474/17474 [==============================] - 98s 6ms/sample - loss: 0.0240 - val_loss: 0.0515
# Epoch 72/100
# 17474/17474 [==============================] - 101s 6ms/sample - loss: 0.0271 - val_loss: 0.0672
# Epoch 73/100
# 17474/17474 [==============================] - 102s 6ms/sample - loss: 0.0272 - val_loss: 0.0395
# Epoch 74/100
# 17474/17474 [==============================] - 104s 6ms/sample - loss: 0.0222 - val_loss: 0.0417
# Epoch 75/100
# 17474/17474 [==============================] - 75s 4ms/sample - loss: 0.0214 - val_loss: 0.0227
# Epoch 76/100
# 17474/17474 [==============================] - 67s 4ms/sample - loss: 0.0229 - val_loss: 0.0220
# Epoch 77/100
# 17474/17474 [==============================] - 69s 4ms/sample - loss: 0.0225 - val_loss: 0.0714
# Epoch 78/100
# 17474/17474 [==============================] - 69s 4ms/sample - loss: 0.0215 - val_loss: 0.0269
# Epoch 79/100
# 17474/17474 [==============================] - 67s 4ms/sample - loss: 0.0268 - val_loss: 0.0305
# Epoch 80/100
# 17474/17474 [==============================] - 69s 4ms/sample - loss: 0.0229 - val_loss: 0.0240
# Epoch 81/100
# 17474/17474 [==============================] - 82s 5ms/sample - loss: 0.0244 - val_loss: 0.0690
# Epoch 82/100
# 17474/17474 [==============================] - 70s 4ms/sample - loss: 0.0266 - val_loss: 0.0291
# Epoch 83/100
# 17474/17474 [==============================] - 67s 4ms/sample - loss: 0.0212 - val_loss: 0.0351
# Epoch 84/100
# 17474/17474 [==============================] - 58s 3ms/sample - loss: 0.0225 - val_loss: 0.0447
# Epoch 85/100
# 17474/17474 [==============================] - 75s 4ms/sample - loss: 0.0233 - val_loss: 0.0235
# Epoch 86/100
# 17474/17474 [==============================] - 79s 4ms/sample - loss: 0.0216 - val_loss: 0.0400
# Epoch 87/100
# 17474/17474 [==============================] - 89s 5ms/sample - loss: 0.0239 - val_loss: 0.0099
# Epoch 88/100
# 17474/17474 [==============================] - 90s 5ms/sample - loss: 0.0218 - val_loss: 0.0172
# Epoch 89/100
# 17474/17474 [==============================] - 85s 5ms/sample - loss: 0.0200 - val_loss: 0.0142
# Epoch 90/100
# 17474/17474 [==============================] - 97s 6ms/sample - loss: 0.0199 - val_loss: 0.0413
# Epoch 91/100
# 17474/17474 [==============================] - 76s 4ms/sample - loss: 0.0244 - val_loss: 0.0782
# Epoch 92/100
# 17474/17474 [==============================] - 97s 6ms/sample - loss: 0.0209 - val_loss: 0.0100
# Epoch 93/100
# 17474/17474 [==============================] - 82s 5ms/sample - loss: 0.0205 - val_loss: 0.0112
# Epoch 94/100
# 17474/17474 [==============================] - 81s 5ms/sample - loss: 0.0199 - val_loss: 0.0668
# Epoch 95/100
# 17474/17474 [==============================] - 76s 4ms/sample - loss: 0.0288 - val_loss: 0.0134
# Epoch 96/100
# 17474/17474 [==============================] - 67s 4ms/sample - loss: 0.0212 - val_loss: 0.0331
# Epoch 97/100
# 17474/17474 [==============================] - 68s 4ms/sample - loss: 0.0223 - val_loss: 0.0101
# Epoch 98/100
# 17474/17474 [==============================] - 81s 5ms/sample - loss: 0.0227 - val_loss: 0.0312
# Epoch 99/100
# 17474/17474 [==============================] - 77s 4ms/sample - loss: 0.0257 - val_loss: 0.0232
# Epoch 100/100
# 17474/17474 [==============================] - 76s 4ms/sample - loss: 0.0211 - val_loss: 0.0193

# %%
#print(lstm1.summary())

# %%
plt.figure(figsize=(15,6))
plt.plot(history1.history["loss"], label="train")
plt.plot(history1.history["val_loss"], label="validation")
plt.legend()

# %%
y_pred = lstm1.predict(X_test)
y_train_inv = yscale.inverse_transform(y_train.reshape(1, -1))
y_test_inv = yscale.inverse_transform(y_test.reshape(1, -1))
y_pred_inv  = yscale.inverse_transform(y_pred)

# %%
plt.figure(figsize=(15,6))
plt.plot(y_test_inv.flatten(), label="Test data")
plt.plot(y_pred_inv.flatten(), label="Model prediction")
plt.legend()

# %%
#test1 = lstm1(X_train[0:1]).numpy()
#test1 = yscale.inverse_transform(test1.reshape(1, -1))
#test2 = float(test1)
#test3 = math.exp(test2)
#print(test3)
#print(test1.shape)
#print(X_train[0:1].shape)

# %%
#lstm1.save("/Users/karangarg/Documents/Year 3 Modules/EC331/Code/rae_repo/lstms/lstm1")
