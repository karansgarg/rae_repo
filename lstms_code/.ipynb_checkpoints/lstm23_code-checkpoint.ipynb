# %%
import numpy as np #Import relevant packages
import pandas as pd
import math
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
import glob
import csv
import matplotlib.pyplot as plt

def unpack_data(filepath): #Returns a dictionary where each item is a df containing one run. One dict per generation.
    all_files = glob.glob(filepath + "/*.csv")
    name_list = []
    datadict = {}
    for f in all_files:
        name_list.append(f[77:-4])
    for i,n in enumerate(name_list):
        datadict[n] = pd.read_csv(all_files[i], header=0)
    for k, v in datadict.items():
        v.drop(columns=["Unnamed: 0", "volume", "spread", "10_MA", "50_MA"], inplace=True)
    return datadict

def format_data(datadict, window): #Turn dictionaries of data into features and samples lists
    x_data = []
    y_data = []
    for k, v in datadict.items():
        for i in range(len(v)):
            if i >= window:
                y_data.append(v.iloc[i]["trading_price"])
                xi = v.iloc[i-window:i].to_numpy()
                x_data.append(xi)
    x_data = np.array(x_data)
    y_data = np.array(y_data)
    y_data = np.reshape(y_data, (y_data.shape[0], 1))
    return x_data, y_data

def normalise_data(xarray, yarray): #Take the natural log and then normalise prices
    yarray_log = np.log(yarray)
    xarray_log = np.log(xarray)
    xsc = StandardScaler()
    instances, timesteps, features = xarray_log.shape
    xarray_log = np.reshape(xarray_log, (-1, features))
    xarray_norm = xsc.fit_transform(xarray_log)
    xarray_norm = np.reshape(xarray_norm, (instances, timesteps, features))
    ysc = StandardScaler().fit(yarray_log)
    yarray_norm = ysc.transform(yarray_log)
    return xarray_norm, yarray_norm, xsc, ysc

def split_data(xarray, yarray, trainratio): #Split the data into training and test sets
    train_len = int(len(xarray)*trainratio)
    test_len = len(xarray) - train_len
    x_train, y_train, x_test, y_test = xarray[:train_len], yarray[:train_len], xarray[train_len:], yarray[train_len:]
    return x_train, y_train, x_test, y_test

# %%
gen22 = unpack_data("/Users/karangarg/Documents/Year 3 Modules/EC331/Code/rae_repo/simulations/gen22_sims/data")

# %%
X23, y23 = format_data(gen22, 20)
print(X23.shape)
print(y23.shape)
# Out:
# (33065, 20, 2)
# (33065, 1)

# %%
X23_train, y23_train, X23_test, y23_test = split_data(X23, y23, 0.8)

# %%
X23_train, y23_train, X23scale, y23scale = normalise_data(X23_train, y23_train)
X23_test, y23_test, _, _ = normalise_data(X23_test, y23_test)

# %%
print(X23scale.mean_)
print(X23scale.var_)
print(y23scale.mean_)
print(y23scale.var_)
# Out:
# [4.70922983 4.80373712]
# [0.11144086 0.01658451]
# [4.71436388]
# [0.11928701]

# %%
lstm23=keras.Sequential() #Set up the architecture of the model

lstm23.add(layers.LSTM(units=16, input_shape=(X23_train.shape[1], X23_train.shape[2])))
lstm23.add(layers.Dropout(0.2))

lstm23.add(layers.Dense(units=1))

print(lstm23.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_1 (LSTM)                (None, 16)                1216
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# ...
# Total params: 1,233
# Trainable params: 1,233
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
lstm23.compile(optimizer='nadam', loss='mean_squared_error') #Compile and train the model

history23 = lstm23.fit(X23_train, y23_train, epochs = 10, batch_size = 32, validation_split=0.2, shuffle=False)
# Out:
# Train on 21161 samples, validate on 5291 samples
# Epoch 1/10
# 21161/21161 [==============================] - 39s 2ms/sample - loss: 0.1302 - val_loss: 0.0187
# Epoch 2/10
# 21161/21161 [==============================] - 30s 1ms/sample - loss: 0.0308 - val_loss: 0.0128
# Epoch 3/10
# 21161/21161 [==============================] - 30s 1ms/sample - loss: 0.0239 - val_loss: 0.0061
# Epoch 4/10
# 21161/21161 [==============================] - 29s 1ms/sample - loss: 0.0198 - val_loss: 0.0086
# Epoch 5/10
# 21161/21161 [==============================] - 31s 1ms/sample - loss: 0.0188 - val_loss: 0.0112
# Epoch 6/10
# 21161/21161 [==============================] - 27s 1ms/sample - loss: 0.0199 - val_loss: 0.0118
# Epoch 7/10
# 21161/21161 [==============================] - 28s 1ms/sample - loss: 0.0175 - val_loss: 0.0014
# Epoch 8/10
# 21161/21161 [==============================] - 27s 1ms/sample - loss: 0.0185 - val_loss: 0.0013
# Epoch 9/10
# ...

# %%
lstm23.save("/Users/karangarg/Documents/Year 3 Modules/EC331/Code/rae_repo/lstms/lstm23")
# Out:
# WARNING:tensorflow:From /Users/karangarg/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1781: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: /Users/karangarg/Documents/Year 3 Modules/EC331/Code/rae_repo/lstms/lstm23/assets

# %%
plt.figure(figsize=(15,6))
plt.plot(history23.history["loss"], label="train")
plt.plot(history23.history["val_loss"], label="validation")
plt.legend()

# %%
y23_pred = lstm23.predict(X23_test)
y23_train_inv = y23scale.inverse_transform(y23_train.reshape(1, -1))
y23_test_inv = y23scale.inverse_transform(y23_test.reshape(1, -1))
y23_pred_inv = y23scale.inverse_transform(y23_pred)

# %%
plt.figure(figsize=(15,6))
plt.plot(y23_test_inv.flatten(), label="Test data")
plt.plot(y23_pred_inv.flatten(), label="Model prediction")
plt.legend()
