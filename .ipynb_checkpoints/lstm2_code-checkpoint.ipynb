# %%
import numpy as np #Import relevant packages
import pandas as pd
import math
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
import glob
import csv
import matplotlib.pyplot as plt

# %%
def unpack_data(filepath): #Returns a dictionary where each item is a df containing one run. One dict per generation.
    all_files = glob.glob(filepath + "/*.csv")
    name_list = []
    datadict = {}
    for f in all_files:
        name_list.append(f[77:-4])
    for i,n in enumerate(name_list):
        datadict[n] = pd.read_csv(all_files[i], header=0)
    for k, v in datadict.items():
        v.drop(columns=["Unnamed: 0", "volume", "spread", "10_MA", "50_MA"], inplace=True)
    return datadict

def format_data(datadict, window): #Turn dictionaries of data into features and samples lists
    x_data = []
    y_data = []
    for k, v in datadict.items():
        for i in range(len(v)):
            if i >= window:
                y_data.append(v.iloc[i]["trading_price"])
                xi = v.iloc[i-window:i].to_numpy()
                x_data.append(xi)
    x_data = np.array(x_data)
    y_data = np.array(y_data)
    y_data = np.reshape(y_data, (y_data.shape[0], 1))
    return x_data, y_data

def normalise_data(xarray, yarray): #Take the natural log and then normalise prices
    yarray_log = np.log(yarray)
    xarray_log = np.log(xarray)
    xsc = StandardScaler()
    instances, timesteps, features = xarray_log.shape
    xarray_log = np.reshape(xarray_log, (-1, features))
    xarray_norm = xsc.fit_transform(xarray_log)
    xarray_norm = np.reshape(xarray_norm, (instances, timesteps, features))
    ysc = StandardScaler().fit(yarray_log)
    yarray_norm = ysc.transform(yarray_log)
    return xarray_norm, yarray_norm, xsc, ysc

def split_data(xarray, yarray, trainratio): #Split the data into training and test sets
    train_len = int(len(xarray)*trainratio)
    test_len = len(xarray) - train_len
    x_train, y_train, x_test, y_test = xarray[:train_len], yarray[:train_len], xarray[train_len:], yarray[train_len:]
    return x_train, y_train, x_test, y_test

# %%
gen1 = unpack_data("/Users/karangarg/Documents/Year 3 Modules/EC331/Code/rae_repo/gen1_sims/data")

# %%
X2, y2 = format_data(gen1, 10)

# %%
#print(X2)
#print(y2)

# %%
X2_train, y2_train, X2_test, y2_test = split_data(X2, y2, 0.8)

# %%
X2_train, y2_train, X2scale, y2scale = normalise_data(X2_train, y2_train)
X2_test, y2_test, _, _ = normalise_data(X2_test, y2_test)

# %%
print(X2scale.mean_)
print(X2scale.var_)
print(y2scale.mean_)
print(y2scale.var_)
#print(X2_train)
#print(y2_train)
# Out:
# [4.70529953 4.78642698]
# [0.05406604 0.01563399]
# [4.70786917]
# [0.05680156]

# %%
lstm2=keras.Sequential() #Set up the architecture of the model

lstm2.add(layers.LSTM(units=50, return_sequences=True, input_shape=(X2_train.shape[1], X2_train.shape[2])))
lstm2.add(layers.Dropout(0.4))

lstm2.add(layers.LSTM(units=50, return_sequences=True))
lstm2.add(layers.Dropout(0.4))

lstm2.add(layers.LSTM(units=50, return_sequences=True))
lstm2.add(layers.Dropout(0.4))

lstm2.add(layers.LSTM(units=50))
lstm2.add(layers.Dropout(0.4))

lstm2.add(layers.Dense(units=1))

# %%
#print(lstm2.summary())

# %%
lstm2.compile(optimizer='nadam', loss='mean_squared_error') #Compile and train the model

history2 = lstm2.fit(X2_train, y2_train, epochs = 100, batch_size = 128, validation_split=0.2, shuffle=False)
# Out:
# Train on 18657 samples, validate on 4665 samples
# Epoch 1/100
# 18657/18657 [==============================] - 66s 4ms/sample - loss: 0.1893 - val_loss: 0.0190
# Epoch 2/100
# 18657/18657 [==============================] - 35s 2ms/sample - loss: 0.1084 - val_loss: 0.0151
# Epoch 3/100
# 18657/18657 [==============================] - 32s 2ms/sample - loss: 0.0781 - val_loss: 0.0404
# Epoch 4/100
# 18657/18657 [==============================] - 34s 2ms/sample - loss: 0.0726 - val_loss: 0.0295
# Epoch 5/100
# 18657/18657 [==============================] - 48s 3ms/sample - loss: 0.0541 - val_loss: 0.0842
# Epoch 6/100
# 18657/18657 [==============================] - 38s 2ms/sample - loss: 0.0582 - val_loss: 0.1332
# Epoch 7/100
# 18657/18657 [==============================] - 36s 2ms/sample - loss: 0.0605 - val_loss: 0.1324
# Epoch 8/100
# 18657/18657 [==============================] - 41s 2ms/sample - loss: 0.0428 - val_loss: 0.0107
# Epoch 9/100
# 18657/18657 [==============================] - 47s 3ms/sample - loss: 0.0339 - val_loss: 0.0049
# Epoch 10/100
# 18657/18657 [==============================] - 39s 2ms/sample - loss: 0.0286 - val_loss: 0.0072
# Epoch 11/100
# 18657/18657 [==============================] - 36s 2ms/sample - loss: 0.0285 - val_loss: 0.0094
# Epoch 12/100
# 18657/18657 [==============================] - 40s 2ms/sample - loss: 0.0274 - val_loss: 0.0310
# Epoch 13/100
# 18657/18657 [==============================] - 38s 2ms/sample - loss: 0.0483 - val_loss: 0.0265
# Epoch 14/100
# 18657/18657 [==============================] - 40s 2ms/sample - loss: 0.1817 - val_loss: 0.0952
# Epoch 15/100
# 18657/18657 [==============================] - 49s 3ms/sample - loss: 0.1030 - val_loss: 0.0649
# Epoch 16/100
# 18657/18657 [==============================] - 39s 2ms/sample - loss: 0.0588 - val_loss: 0.0163
# Epoch 17/100
# 18657/18657 [==============================] - 46s 2ms/sample - loss: 0.0497 - val_loss: 0.0911
# Epoch 18/100
# 18657/18657 [==============================] - 41s 2ms/sample - loss: 0.0514 - val_loss: 0.0090
# Epoch 19/100
# 18657/18657 [==============================] - 42s 2ms/sample - loss: 0.0333 - val_loss: 0.0048
# Epoch 20/100
# 18657/18657 [==============================] - 43s 2ms/sample - loss: 0.0415 - val_loss: 0.0052
# Epoch 21/100
# 18657/18657 [==============================] - 39s 2ms/sample - loss: 0.0352 - val_loss: 0.0093
# Epoch 22/100
# 18657/18657 [==============================] - 38s 2ms/sample - loss: 0.0744 - val_loss: 0.0089
# Epoch 23/100
# 18657/18657 [==============================] - 44s 2ms/sample - loss: 0.0350 - val_loss: 0.0101
# Epoch 24/100
# 18657/18657 [==============================] - 39s 2ms/sample - loss: 0.0307 - val_loss: 0.0074
# Epoch 25/100
# 18657/18657 [==============================] - 38s 2ms/sample - loss: 0.0259 - val_loss: 0.0049
# Epoch 26/100
# 18657/18657 [==============================] - 41s 2ms/sample - loss: 0.0263 - val_loss: 0.0110
# Epoch 27/100
# 18657/18657 [==============================] - 40s 2ms/sample - loss: 0.0311 - val_loss: 0.0330
# Epoch 28/100
# 18657/18657 [==============================] - 43s 2ms/sample - loss: 0.0781 - val_loss: 0.0453
# Epoch 29/100
# 18657/18657 [==============================] - 43s 2ms/sample - loss: 0.0386 - val_loss: 0.0052
# Epoch 30/100
# 18657/18657 [==============================] - 47s 3ms/sample - loss: 0.0265 - val_loss: 0.0028
# Epoch 31/100
# 18657/18657 [==============================] - 42s 2ms/sample - loss: 0.0245 - val_loss: 0.0052
# Epoch 32/100
# 18657/18657 [==============================] - 52s 3ms/sample - loss: 0.0253 - val_loss: 0.0029
# Epoch 33/100
# 18657/18657 [==============================] - 46s 2ms/sample - loss: 0.0296 - val_loss: 0.0063
# Epoch 34/100
# 18657/18657 [==============================] - 50s 3ms/sample - loss: 0.0852 - val_loss: 0.1265
# Epoch 35/100
# 18657/18657 [==============================] - 38s 2ms/sample - loss: 0.0625 - val_loss: 0.0146
# Epoch 36/100
# 18657/18657 [==============================] - 40s 2ms/sample - loss: 0.0385 - val_loss: 0.0255
# Epoch 37/100
# 18657/18657 [==============================] - 37s 2ms/sample - loss: 0.0366 - val_loss: 0.0026
# Epoch 38/100
# 18657/18657 [==============================] - 39s 2ms/sample - loss: 0.0540 - val_loss: 0.0314
# Epoch 39/100
# 18657/18657 [==============================] - 39s 2ms/sample - loss: 0.0400 - val_loss: 0.0048
# Epoch 40/100
# 18657/18657 [==============================] - 42s 2ms/sample - loss: 0.0278 - val_loss: 0.0023
# Epoch 41/100
# 18657/18657 [==============================] - 46s 2ms/sample - loss: 0.0324 - val_loss: 0.0025
# Epoch 42/100
# 18657/18657 [==============================] - 48s 3ms/sample - loss: 0.0297 - val_loss: 0.0035
# Epoch 43/100
# 18657/18657 [==============================] - 40s 2ms/sample - loss: 0.0463 - val_loss: 0.0164
# Epoch 44/100
# 18657/18657 [==============================] - 39s 2ms/sample - loss: 0.0325 - val_loss: 0.0084
# Epoch 45/100
# 18657/18657 [==============================] - 39s 2ms/sample - loss: 0.0305 - val_loss: 0.0026
# Epoch 46/100
# 18657/18657 [==============================] - 48s 3ms/sample - loss: 0.0434 - val_loss: 0.0080
# Epoch 47/100
# 18657/18657 [==============================] - 37s 2ms/sample - loss: 0.0310 - val_loss: 0.0023
# Epoch 48/100
# 18657/18657 [==============================] - 40s 2ms/sample - loss: 0.0513 - val_loss: 0.0400
# Epoch 49/100
# 18657/18657 [==============================] - 39s 2ms/sample - loss: 0.0426 - val_loss: 0.0227
# Epoch 50/100
# 18657/18657 [==============================] - 38s 2ms/sample - loss: 0.0358 - val_loss: 0.0039
# Epoch 51/100
# 18657/18657 [==============================] - 37s 2ms/sample - loss: 0.0349 - val_loss: 0.0043
# Epoch 52/100
# 18657/18657 [==============================] - 42s 2ms/sample - loss: 0.0434 - val_loss: 0.0179
# Epoch 53/100
# 18657/18657 [==============================] - 43s 2ms/sample - loss: 0.0311 - val_loss: 0.0028
# Epoch 54/100
# 18657/18657 [==============================] - 38s 2ms/sample - loss: 0.0236 - val_loss: 0.0021
# Epoch 55/100
# 18657/18657 [==============================] - 41s 2ms/sample - loss: 0.0279 - val_loss: 0.0067
# Epoch 56/100
# 18657/18657 [==============================] - 42s 2ms/sample - loss: 0.0278 - val_loss: 0.0026
# Epoch 57/100
# 18657/18657 [==============================] - 44s 2ms/sample - loss: 0.0280 - val_loss: 0.0027
# Epoch 58/100
# 18657/18657 [==============================] - 40s 2ms/sample - loss: 0.0320 - val_loss: 0.0060
# Epoch 59/100
# 18657/18657 [==============================] - 38s 2ms/sample - loss: 0.0498 - val_loss: 0.0091
# Epoch 60/100
# 18657/18657 [==============================] - 41s 2ms/sample - loss: 0.0394 - val_loss: 0.0782
# Epoch 61/100
# 18657/18657 [==============================] - 45s 2ms/sample - loss: 0.0541 - val_loss: 0.0202
# Epoch 62/100
# 18657/18657 [==============================] - 46s 2ms/sample - loss: 0.0416 - val_loss: 0.0254
# Epoch 63/100
# 18657/18657 [==============================] - 52s 3ms/sample - loss: 0.0332 - val_loss: 0.0038
# Epoch 64/100
# 18657/18657 [==============================] - 62s 3ms/sample - loss: 0.0268 - val_loss: 0.0030
# Epoch 65/100
# 18657/18657 [==============================] - 48s 3ms/sample - loss: 0.0574 - val_loss: 0.0088
# Epoch 66/100
# 18657/18657 [==============================] - 46s 2ms/sample - loss: 0.0590 - val_loss: 0.0049
# Epoch 67/100
# 18657/18657 [==============================] - 43s 2ms/sample - loss: 0.0259 - val_loss: 0.0102
# Epoch 68/100
# 18657/18657 [==============================] - 44s 2ms/sample - loss: 0.0280 - val_loss: 0.0095
# Epoch 69/100
# 18657/18657 [==============================] - 45s 2ms/sample - loss: 0.0305 - val_loss: 0.0391
# Epoch 70/100
# 18657/18657 [==============================] - 64s 3ms/sample - loss: 0.0419 - val_loss: 0.0063
# Epoch 71/100
# 18657/18657 [==============================] - 49s 3ms/sample - loss: 0.0381 - val_loss: 0.0502
# Epoch 72/100
# 18657/18657 [==============================] - 49s 3ms/sample - loss: 0.0417 - val_loss: 0.0028
# Epoch 73/100
# 18657/18657 [==============================] - 40s 2ms/sample - loss: 0.0456 - val_loss: 0.0318
# Epoch 74/100
# 18657/18657 [==============================] - 37s 2ms/sample - loss: 0.0536 - val_loss: 0.0067
# Epoch 75/100
# 18657/18657 [==============================] - 38s 2ms/sample - loss: 0.0570 - val_loss: 0.0214
# Epoch 76/100
# 18657/18657 [==============================] - 37s 2ms/sample - loss: 0.0293 - val_loss: 0.0036
# Epoch 77/100
# 18657/18657 [==============================] - 37s 2ms/sample - loss: 0.0426 - val_loss: 0.0094
# Epoch 78/100
# 18657/18657 [==============================] - 37s 2ms/sample - loss: 0.0258 - val_loss: 0.0047
# Epoch 79/100
# 18657/18657 [==============================] - 37s 2ms/sample - loss: 0.0237 - val_loss: 0.0019
# Epoch 80/100
# 18657/18657 [==============================] - 42s 2ms/sample - loss: 0.0312 - val_loss: 0.0186
# Epoch 81/100
# 18657/18657 [==============================] - 41s 2ms/sample - loss: 0.0355 - val_loss: 0.0056
# Epoch 82/100
# 18657/18657 [==============================] - 42s 2ms/sample - loss: 0.0471 - val_loss: 0.0357
# Epoch 83/100
# 18657/18657 [==============================] - 44s 2ms/sample - loss: 0.0360 - val_loss: 0.0072
# Epoch 84/100
# 18657/18657 [==============================] - 50s 3ms/sample - loss: 0.0592 - val_loss: 0.0084
# Epoch 85/100
# 18657/18657 [==============================] - 52s 3ms/sample - loss: 0.0258 - val_loss: 0.0022
# Epoch 86/100
# 18657/18657 [==============================] - 42s 2ms/sample - loss: 0.0333 - val_loss: 0.0131
# Epoch 87/100
# 18657/18657 [==============================] - 42s 2ms/sample - loss: 0.0284 - val_loss: 0.0034
# Epoch 88/100
# 18657/18657 [==============================] - 42s 2ms/sample - loss: 0.0464 - val_loss: 0.0095
# Epoch 89/100
# 18657/18657 [==============================] - 49s 3ms/sample - loss: 0.0249 - val_loss: 0.0019
# Epoch 90/100
# 18657/18657 [==============================] - 42s 2ms/sample - loss: 0.0340 - val_loss: 0.0178
# Epoch 91/100
# 18657/18657 [==============================] - 43s 2ms/sample - loss: 0.0320 - val_loss: 0.0051
# Epoch 92/100
# 18657/18657 [==============================] - 52s 3ms/sample - loss: 0.0604 - val_loss: 0.0068
# Epoch 93/100
# 18657/18657 [==============================] - 40s 2ms/sample - loss: 0.0299 - val_loss: 0.0032
# Epoch 94/100
# 18657/18657 [==============================] - 40s 2ms/sample - loss: 0.0432 - val_loss: 0.0089
# Epoch 95/100
# 18657/18657 [==============================] - 40s 2ms/sample - loss: 0.0253 - val_loss: 0.0027
# Epoch 96/100
# 18657/18657 [==============================] - 41s 2ms/sample - loss: 0.0242 - val_loss: 0.0085
# Epoch 97/100
# 18657/18657 [==============================] - 42s 2ms/sample - loss: 0.0239 - val_loss: 0.0031
# Epoch 98/100
# 18657/18657 [==============================] - 40s 2ms/sample - loss: 0.0247 - val_loss: 0.0074
# Epoch 99/100
# 18657/18657 [==============================] - 40s 2ms/sample - loss: 0.0249 - val_loss: 0.0082
# Epoch 100/100
# 18657/18657 [==============================] - 41s 2ms/sample - loss: 0.0244 - val_loss: 0.0037

# %%
lstm2.save("/Users/karangarg/Documents/Year 3 Modules/EC331/Code/rae_repo/lstms/lstm2")
# Out:
# WARNING:tensorflow:From /Users/karangarg/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1781: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: /Users/karangarg/Documents/Year 3 Modules/EC331/Code/rae_repo/lstms/lstm2/assets

# %%
plt.figure(figsize=(12,6))
plt.plot(history2.history["loss"], label="train")
plt.plot(history2.history["val_loss"], label="validation")
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %%
y2_pred = lstm2.predict(X2_test)
y2_train_inv = y2scale.inverse_transform(y2_train.reshape(1, -1))
y2_test_inv = y2scale.inverse_transform(y2_test.reshape(1, -1))
y2_pred_inv  = y2scale.inverse_transform(y2_pred)

# %%
plt.figure(figsize=(15,6))
plt.plot(y2_test_inv.flatten(), label="Test data")
plt.plot(y2_pred_inv.flatten(), label="Model prediction")
plt.legend()
